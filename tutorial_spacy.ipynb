# %%
# Carregue o modelo
import spacy
import pt_core_news_sm

nlp = pt_core_news_sm.load()

# %%
texto = nlp('Maria mora em Paris')

# Interando sobre as entidades identificadas na frase
for entidade in texto.ents:
  print(entidade.text, entidade.label_)
# Out:
# Maria PER
# Paris LOC

# %%
# Destacando visualmente as entidades da frase e seus tipos
spacy.displacy.render(texto, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  mora em
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>

# %%
# Visualização do Analisador de Dependência
spacy.displacy.render(texto, style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="b849ca3aac334f5d8070bc01f011b653-0" class="displacy" width="750" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Maria</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">mora</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">em</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Paris</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b849ca3aac334f5d8070bc01f011b653-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b849ca3aac334f5d8070bc01f011b653-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b849ca3aac334f5d8070bc01f011b653-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b849ca3aac334f5d8070bc01f011b653-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b849ca3aac334f5d8070bc01f011b653-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b849ca3aac334f5d8070bc01f011b653-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# Ver a definição do tipo de entidade
print("PER:", spacy.explain('PER'))
print("LOC:", spacy.explain('LOC'))
print("ORG:", spacy.explain('ORG'))
print("MISC:", spacy.explain('MISC'))
# Out:
# PER: Named person or family.
# LOC: Non-GPE locations, mountain ranges, bodies of water
# ORG: Companies, agencies, institutions, etc.
# MISC: Miscellaneous entities, e.g. events, nationalities, products or works of art

# %%
text = nlp("Juliana nasceu no dia 18/06/2018 em Fortaleza")
spacy.displacy.render(text, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Juliana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  nasceu no dia 18/06/2018 em
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fortaleza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>

# %%
import pandas as pd  
from collections import Counter #for counting
import seaborn as sns #for visualization

# %%
nlp = pt_core_news_sm.load()

# %%
tweets = pd.read_csv("ignore_tweets.csv")
tweets.head(2)
# Out:
#    Unnamed: 0                      Created At  \
# 0           0  Sun Jan 08 01:22:05 +0000 2017
# 1           1  Sun Jan 08 01:49:01 +0000 2017
#
#                                                 Text  \
# 0  ���⛪ @ Catedral de Santo Antônio - Governador ...
# 1  � @ Governador Valadares, Minas Gerais https:/...
#
#    Geo Coordinates.latitude  Geo Coordinates.longitude User Location  \
# 0                       NaN                        NaN        Brasil
# 1                  -41.9333                     -18.85           NaN
#
#                Username User Screen Name  Retweet Count Classificacao  ...  \
# 0  Leonardo C Schneider    LeoCSchneider              0        Neutro  ...
# 1               Wândell         klefnews              0        Neutro  ...
#
#   Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
#
# [2 rows x 26 columns]

# %%
tweets.shape
# Out:
# (8199, 26)

# %%
import random
random.seed(44)
text = tweets.Text[random.sample(range(1,100),50)]
text
# Out:
# 53    #beta #betalab #mg Pedido ao STF irritou Meire...
# 67    #EducaçãoMG Governo de Minas Gerais reconhece ...
# 70    #i5gornascimento @i5gornascimento @cristiano U...
# 90    #musicagratis Fundação Hospitalar do Estado de...
# 15    "Los abusos, aun en el estado más sólido, son ...
# 23    "Praia da Estação" lota neste sábado de verão ...
# 49    #beta #betalab #mg Nos últimos dois anos: Gove...
# 29    #Alerta - Nome da CEEE é utilizado em golpe no...
# 38    #beta #betalab #mg Estado afirma não ter sido ...
# 4     ��� PSOL vai questionar aumento de vereadores ...
# 92    #musicagratis Prefeitura de Rodeiro: A Prefeit...
# 95    #noticiasdorenan Uso de depósitos judiciais pe...
# 73    #i5gornascimento @i5gornascimento g1 Vereadore...
# 2     �� @ Governador Valadares, Minas Gerais https:...
# 13    "La La Land: Cantando Estações" arrasa no Glob...
# 21    "O governo federal publicou no dia 27 de dezem...
# 66    #EBC Governo de Minas investiga casos suspeito...
# 39    #beta #betalab #mg Estado de espírito do pauli...
# 93    #noticiasdorenan Em calamidade financeira, gov...
# 76    #ImpeachmentPimentel #PTNuncaMais \nMesmo em c...
# 52    #beta #betalab #mg Pede respeito aos direitos ...
# 42    #beta #betalab #mg Ex-presidente da Câmara: Ju...
# 46    #beta #betalab #mg Massacre em presídio de Man...
# 10    "Daí a gente visita governador valadares"\n"Qu...
# 44    #beta #betalab #mg Mais sobre o massacre: PF: ...
# 37    #beta #betalab #mg Escalada de violência: Crim...
# 84    #Mídia:  Press Release from Business Wire : Di...
# 88    #Minas vai dobrar oferta de trabalho e estudo ...
# 83    #Mídia:  Press Release from Business Wire : Co...
# 9     "com vcs bh fica pequena!" Belo Horizonte (pro...
# 85    #Mídia:  Press Release from Business Wire : IB...
# 35    #beta #betalab #mg Crise política no DF se agr...
# 41    #beta #betalab #mg Ex-ministro e outros: Servi...
# 14    "La La Land: Cantando Estações" arrasa no Glob...
# 91    #musicagratis Ministério Público de Minas Gera...
# 5     " bom é bandido morto"\nDeputado Cabo Júlio é ...
# 94    #noticiasdorenan Governo de Minas Gerais recon...
# 25    "uso de aeronave pertencente ao  Estado de MG,...
# 7     "A gigantesca barba do mal" em destaque no cad...
# 31    #beta #betalab #mg Caos nos presídios: AM pede...
# 60    #beta #betalab #mg UOL Confere: Governo Temer ...
# 69    #holachilevierneschico jajaja los wns preparad...
# 58    #beta #betalab #mg 'Tinha que matar mais': Sec...
# 97    #OperacaoBetaLab #TimBeta #Beta #BetaLab #Beta...
# 17    "Modelo de segurança será o nosso legado", diz...
# 48    #beta #betalab #mg Muitas páginas de investiga...
# 16    "Mesmo sem muito dinheiro no caixa o governo d...
# 50    #beta #betalab #mg Nova chacina em presídio: P...
# 96    #OperacaoBetaLab #TimBeta #Beta #BetaLab #Beta...
# 3                           ��� https://t.co/BnDsO34qK0
# Name: Text, dtype: object

# %%
text_combined = str(text)

# %%
doc = nlp(text_combined)

# %%
for ent in doc.ents:
  print(ent.text, " -> ", ent.label_)
# Out:
# Pedido  ->  LOC
# STF  ->  LOC
# Meire  ->  LOC
# EducaçãoMG Governo  ->  MISC
# Minas Gerais  ->  LOC
# Fundação Hospitalar do Estado  ->  LOC
# Los  ->  LOC
# Praia da Estação  ->  LOC
# Gove...
# 29    #  ->  MISC
# Alerta - Nome da CEEE  ->  ORG
# Estado  ->  LOC
# PSOL  ->  PER
# Prefeitura de Rodeiro:  ->  LOC
# Prefeit...
# 95  ->  MISC
# Governador Valadares  ->  LOC
# Minas Gerais  ->  LOC
# La La Land: Cantando Estações  ->  MISC
# Glob  ->  LOC
# EBC Governo de Minas  ->  LOC
# Estado  ->  LOC
# ImpeachmentPimentel  ->  MISC
# PTNuncaMais  ->  MISC
# Pede  ->  LOC
# Câmara:  ->  LOC
# Massacre  ->  MISC
# Man...  ->  MISC
# Escalada  ->  MISC
# Crim  ->  LOC
# Minas  ->  LOC
# vcs bh  ->  LOC
# Belo Horizonte  ->  LOC
# Crise política  ->  MISC
# DF  ->  LOC
# Servi  ->  LOC
# La La Land: Cantando Estações  ->  MISC
# Glob  ->  LOC
# Ministério Público de Minas Gera...  ->  LOC
# Cabo Júlio  ->  LOC
# Governo de Minas Gerais  ->  LOC
# Estado  ->  LOC
# Caos  ->  LOC
# UOL  ->  MISC
# OperacaoBetaLab #TimBeta #  ->  MISC
# Modelo de segurança  ->  MISC
# Muitas  ->  ORG
# Nova chacina  ->  LOC
# OperacaoBetaLab #TimBeta #  ->  MISC

# %%
spacy.displacy.render(doc, style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">53    #beta #betalab #mg
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pedido
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ao
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     STF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  irritou
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Meire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ...</br>67    #
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EducaçãoMG Governo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minas Gerais
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  reconhece ...</br>70    #i5gornascimento @i5gornascimento @cristiano U...</br>90    #musicagratis
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fundação Hospitalar do Estado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  de...</br>15    &quot;
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Los
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  abusos, aun en el estado más sólido, son ...</br>23    &quot;
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Praia da Estação
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# &quot; lota neste sábado de verão ...</br>49    #beta #betalab #mg Nos últimos dois anos:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gove...
# 29    #
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alerta - Nome da CEEE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  é utilizado em golpe no...</br>38    #beta #betalab #mg
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Estado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  afirma não ter sido ...</br>4     ���
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PSOL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  vai questionar aumento de vereadores ...</br>92    #musicagratis
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prefeitura de Rodeiro:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  A
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prefeit...
# 95
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#     #noticiasdorenan Uso de depósitos judiciais pe...</br>73    #i5gornascimento @i5gornascimento g1 Vereadore...</br>2     �� @
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Governador Valadares
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minas Gerais
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  https:...</br>13    &quot;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     La La Land: Cantando Estações
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# &quot; arrasa no
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Glob
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ...</br>21    &quot;O governo federal publicou no dia 27 de dezem...</br>66    #
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EBC Governo de Minas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  investiga casos suspeito...</br>39    #beta #betalab #mg
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Estado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  de espírito do pauli...</br>93    #noticiasdorenan Em calamidade financeira, gov...</br>76    #
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ImpeachmentPimentel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  #
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PTNuncaMais
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  \nMesmo em c...</br>52    #beta #betalab #mg
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pede
#     <span style="font-size: 0.8em; font-weight: bold; line-height:

# %%
for token in doc:
  print(token)
# Out:
# 53
#
# #
# beta
# #
# betalab
# #
# mg
# Pedido
# ao
# STF
# irritou
# Meire
# ...
#
#
# 67
#
# #
# EducaçãoMG
# Governo
# de
# Minas
# Gerais
# reconhece
# ...
#
#
# 70
#
# #
# i5gornascimento
# @i5gornascimento
# @cristiano
# U
# ...
#
#
# 90
#
# #
# musicagratis
# Fundação
# Hospitalar
# do
# Estado
# de
# ...
#
#
# 15
#
# "
# Los
# abusos
# ,
# aun
# en
# el
# estado
# más
# sólido
# ,
# son
# ...
#
#
# 23
#
# "
# Praia
# da
# Estação
# "
# lota
# neste
# sábado
# de
# verão
# ...
#
#
# 49
#
# #
# beta
# #
# betalab
# #
# mg
# Nos
# últimos
# dois
# anos
# :
# Gove
# ...
#
#
# 29
#
# #
# Alerta
# -
# Nome
# da
# CEEE
# é
# utilizado
# em
# golpe
# no
# ...
#
#
# 38
#
# #
# beta
# #
# betalab
# #
# mg
# Estado
# afirma
# não
# ter
# sido
# ...
#
#
# 4
#
# �
# �
# �
# PSOL
# vai
# questionar
# aumento
# de
# vereadores
# ...
#
#
# 92
#
# #
# musicagratis
# Prefeitura
# de
# Rodeiro
# :
# A
# Prefeit
# ...
#
#
# 95
#
# #
# noticiasdorenan
# Uso
# de
# depósitos
# judiciais
# pe
# ...
#
#
# 73
#
# #
# i5gornascimento
# @i5gornascimento
# g1
# Vereadore
# ...
#
#
# 2
#
# �
# �
# @
# Governador
# Valadares
# ,
# Minas
# Gerais
# https
# :
# ...
#
#
# 13
#
# "
# La
# La
# Land
# :
# Cantando
# Estações
# "
# arrasa
# no
# Glob
# ...
#
#
# 21
#
# "
# O
# governo
# federal
# publicou
# no
# dia
# 27
# de
# dezem
# ...
#
#
# 66
#
# #
# EBC
# Governo
# de
# Minas
# investiga
# casos
# suspeito
# ...
#
#
# 39
#
# #
# beta
# #
# betalab
# #
# mg
# Estado
# de
# espírito
# do
# pauli
# ...
#
#
# 93
#
# #
# noticiasdorenan
# Em
# calamidade
# financeira
# ,
# gov
# ...
#
#
# 76
#
# #
# ImpeachmentPimentel
# #
# PTNuncaMais
# \nMesmo
# em
# c
# ...
#
#
# 52
#
# #
# beta
# #
# betalab
# #
# mg
# Pede
# respeito
# aos
# direitos
# ...
#
#
# 42
#
# #
# beta
# #
# betalab
# #
# mg
# Ex-presidente
# da
# Câmara
# :
# Ju
# ...
#
#
# 46
#
# #
# beta
# #
# betalab
# #
# mg
# Massacre
# em
# presídio
# de
# Man
# ...
#
#
# 10
#
# "
# Daí
# a
# gente
# visita
# governador
# valadares"\n"Qu
# ...
#
#
# 44
#
# #
# beta
# #
# betalab
# #
# mg
# Mais
# sobre
# o
# massacre
# :
# PF
# :
# ...
#
#
# 37
#
# #
# beta
# #
# betalab
# #
# mg
# Escalada
# de
# violência
# :
# Crim
# ...
#
#
# 84
#
# #
# Mídia
# :
#
# Press
# Release
# from
# Business
# Wire
# :
# Di
# ...
#
#
# 88
#
# #
# Minas
# vai
# dobrar
# oferta
# de
# trabalho
# e
# estudo
# ...
#
#
# 83
#
# #
# Mídia
# :
#
# Press
# Release
# from
# Business
# Wire
# :
# Co
# ...
#
#
# 9
#
# "
# com
# vcs
# bh
# fica
# pequena
# !
# "
# Belo
# Horizonte
# (
# pro
# ...
#
#
# 85
#
# #
# Mídia
# :
#
# Press
# Release
# from
# Business
# Wire
# :
# IB
# ...
#
#
# 35
#
# #
# beta
# #
# betalab
# #
# mg
# Crise
# política
# no
# DF
# se
# agr
# ...
#
#
# 41
#
# #
# beta
# #
# betalab
# #
# mg
# Ex-ministro
# e
# outros
# :
# Servi
# ...
#
#
# 14
#
# "
# La
# La
# Land
# :
# Cantando
# Estações
# "
# arrasa
# no
# Glob
# ...
#
#
# 91
#
# #
# musicagratis
# Ministério
# Público
# de
# Minas
# Gera
# ...
#
#
# 5
#
# "
# bom
# é
# bandido
# morto"\nDeputado
# Cabo
# Júlio
# é
# ...
#
#
# 94
#
# #
# noticiasdorenan
# Governo
# de
# Minas
# Gerais
# recon
# ...
#
#
# 25
#
# "
# uso
# de
# aeronave
# pertencente
# ao
#
# Estado
# de
# MG
# ,
# ...
#
#
# 7
#
# "
# A
# gigantesca
# barba
# do
# mal
# "
# em
# destaque
# no
# cad
# ...
#
#
# 31
#
# #
# beta
# #
# betalab
# #
# mg
# Caos
# nos
# presídios
# :
# AM
# pede
# ...
#
#
# 60
#
# #
# beta
# #
# betalab
# #
# mg
# UOL
# Confere
# :
# Governo
# Temer
# ...
#
#
# 69
#
# #
# holachilevierneschico
# jajaja
# los
# wns
# preparad
# ...
#
#
# 58
#
# #
# beta
# #
# betalab
# #
# mg
# '
# Tinha
# que
# matar
# mais
# '
# :
# Sec
# ...
#
#
# 97
#
# #
# OperacaoBetaLab
# #
# TimBeta
# #
# Beta
# #
# BetaLab
# #
# Beta
# ...
#
#
# 17
#
# "
# Modelo
# de
# segurança
# será
# o
# nosso
# legado
# "
# ,
# diz
# ...
#
#
# 48
#
# #
# beta
# #
# betalab
# #
# mg
# Muitas
# páginas
# de
# investiga
# ...
#
#
# 16
#
# "
# Mesmo
# sem
# muito
# dinheiro
# no
# caixa
# o
# governo
# d
# ...
#
#
# 50
#
# #
# beta
# #
# betalab
# #
# mg
# Nova
# chacina
# em
# presídio
# :
# P
# ...
#
#
# 96
#
# #
# OperacaoBetaLab
# #
# TimBeta
# #
# Beta
# #
# BetaLab
# #
# Beta
# ...
#
#
# 3
#
# �
# �
# �
# https://t.co/BnDsO34qK0
#
#
# Name
# :
# Text
# ,
# dtype
# :
# object

# %%
for token in doc:
  print(token.text, token.pos_)
# Out:
# 53 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg NOUN
# Pedido NOUN
# ao ADP
# STF PROPN
# irritou VERB
# Meire PROPN
# ... PUNCT
#
#  SPACE
# 67 NUM
#     SPACE
# # ADV
# EducaçãoMG PROPN
# Governo PROPN
# de ADP
# Minas PROPN
# Gerais PROPN
# reconhece VERB
# ... PUNCT
#
#  SPACE
# 70 NUM
#     SPACE
# # ADV
# i5gornascimento NOUN
# @i5gornascimento NOUN
# @cristiano ADJ
# U PROPN
# ... PUNCT
#
#  SPACE
# 90 NUM
#     SPACE
# # ADV
# musicagratis PROPN
# Fundação PROPN
# Hospitalar PROPN
# do ADP
# Estado NOUN
# de ADP
# ... PUNCT
#
#  SPACE
# 15 NUM
#     SPACE
# " PUNCT
# Los X
# abusos ADJ
# , PUNCT
# aun PROPN
# en PROPN
# el PROPN
# estado NOUN
# más ADJ
# sólido ADJ
# , PUNCT
# son INTJ
# ... PUNCT
#
#  SPACE
# 23 NUM
#     SPACE
# " PUNCT
# Praia PROPN
# da ADP
# Estação PROPN
# " PUNCT
# lota NOUN
# neste ADP
# sábado NOUN
# de ADP
# verão NOUN
# ... PUNCT
#
#  SPACE
# 49 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg NOUN
# Nos ADP
# últimos ADJ
# dois NUM
# anos NOUN
# : PUNCT
# Gove PROPN
# ... PUNCT
#
#  SPACE
# 29 NUM
#     SPACE
# # ADV
# Alerta PROPN
# - PUNCT
# Nome PROPN
# da ADP
# CEEE PROPN
# é AUX
# utilizado VERB
# em ADP
# golpe NOUN
# no ADP
# ... PUNCT
#
#  SPACE
# 38 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg PROPN
# Estado NOUN
# afirma VERB
# não ADV
# ter AUX
# sido AUX
# ... PUNCT
#
#  SPACE
# 4 NUM
#      SPACE
# � NOUN
# � PROPN
# � PROPN
# PSOL PROPN
# vai AUX
# questionar VERB
# aumento NOUN
# de ADP
# vereadores NOUN
# ... PUNCT
#
#  SPACE
# 92 NUM
#     SPACE
# # ADV
# musicagratis PROPN
# Prefeitura NOUN
# de ADP
# Rodeiro PROPN
# : PUNCT
# A DET
# Prefeit PROPN
# ... PUNCT
#
#  SPACE
# 95 NUM
#     SPACE
# # ADV
# noticiasdorenan ADJ
# Uso NOUN
# de ADP
# depósitos NOUN
# judiciais ADJ
# pe PROPN
# ... PUNCT
#
#  SPACE
# 73 NUM
#     SPACE
# # ADV
# i5gornascimento NOUN
# @i5gornascimento NOUN
# g1 ADJ
# Vereadore PROPN
# ... PUNCT
#
#  SPACE
# 2 NUM
#      SPACE
# � PROPN
# � NOUN
# @ ADJ
# Governador NOUN
# Valadares PROPN
# , PUNCT
# Minas PROPN
# Gerais PROPN
# https PROPN
# : PUNCT
# ... PUNCT
#
#  SPACE
# 13 NUM
#     SPACE
# " PUNCT
# La PROPN
# La PROPN
# Land PROPN
# : PUNCT
# Cantando VERB
# Estações PROPN
# " PUNCT
# arrasa NOUN
# no ADP
# Glob PROPN
# ... PUNCT
#
#  SPACE
# 21 NUM
#     SPACE
# " PUNCT
# O DET
# governo NOUN
# federal ADJ
# publicou VERB
# no ADP
# dia NOUN
# 27 NUM
# de ADP
# dezem VERB
# ... PUNCT
#
#  SPACE
# 66 NUM
#     SPACE
# # ADV
# EBC PROPN
# Governo PROPN
# de ADP
# Minas PROPN
# investiga PROPN
# casos NOUN
# suspeito ADJ
# ... PUNCT
#
#  SPACE
# 39 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg PROPN
# Estado NOUN
# de ADP
# espírito NOUN
# do ADP
# pauli NOUN
# ... PUNCT
#
#  SPACE
# 93 NUM
#     SPACE
# # ADV
# noticiasdorenan ADJ
# Em ADP
# calamidade NOUN
# financeira ADJ
# , PUNCT
# gov ADJ
# ... PUNCT
#
#  SPACE
# 76 NUM
#     SPACE
# # ADV
# ImpeachmentPimentel PROPN
# # ADV
# PTNuncaMais ADJ
# \nMesmo NOUN
# em ADP
# c NOUN
# ... PUNCT
#
#  SPACE
# 52 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg PROPN
# Pede PROPN
# respeito NOUN
# aos ADP
# direitos NOUN
# ... PUNCT
#
#  SPACE
# 42 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg PROPN
# Ex-presidente NOUN
# da ADP
# Câmara NOUN
# : PUNCT
# Ju PROPN
# ... PUNCT
#
#  SPACE
# 46 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg PROPN
# Massacre NOUN
# em ADP
# presídio NOUN
# de ADP
# Man NOUN
# ... PUNCT
#
#  SPACE
# 10 NUM
#     SPACE
# " PUNCT
# Daí ADV
# a DET
# gente NOUN
# visita VERB
# governador NOUN
# valadares"\n"Qu ADJ
# ... PUNCT
#
#  SPACE
# 44 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg VERB
# Mais ADV
# sobre ADP
# o DET
# massacre NOUN
# : PUNCT
# PF PROPN
# : PUNCT
# ... PUNCT
#
#  SPACE
# 37 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg NOUN
# Escalada PROPN
# de ADP
# violência NOUN
# : PUNCT
# Crim PROPN
# ... PUNCT
#
#  SPACE
# 84 NUM
#     SPACE
# # ADV
# Mídia VERB
# : PUNCT
#   SPACE
# Press PROPN
# Release PROPN
# from PROPN
# Business PROPN
# Wire PROPN
# : PUNCT
# Di PROPN
# ... PUNCT
#
#  SPACE
# 88 NUM
#     SPACE
# # ADV
# Minas PROPN
# vai AUX
# dobrar VERB
# oferta NOUN
# de ADP
# trabalho NOUN
# e CCONJ
# estudo NOUN
# ... PUNCT
#
#  SPACE
# 83 NUM
#     SPACE
# # ADV
# Mídia VERB
# : PUNCT
#   SPACE
# Press PROPN
# Release PROPN
# from PROPN
# Business PROPN
# Wire PROPN
# : PUNCT
# Co PROPN
# ... PUNCT
#
#  SPACE
# 9 NUM
#      SPACE
# " PUNCT
# com ADP
# vcs PROPN
# bh PROPN
# fica VERB
# pequena ADJ
# ! PUNCT
# " PUNCT
# Belo PROPN
# Horizonte PROPN
# ( PUNCT
# pro NOUN
# ... PUNCT
#
#  SPACE
# 85 NUM
#     SPACE
# # ADV
# Mídia VERB
# : PUNCT
#   SPACE
# Press PROPN
# Release PROPN
# from PROPN
# Business PROPN
# Wire PROPN
# : PUNCT
# IB PROPN
# ... PUNCT
#
#  SPACE
# 35 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg PROPN
# Crise NOUN
# política ADJ
# no ADP
# DF PROPN
# se PRON
# agr VERB
# ... PUNCT
#
#  SPACE
# 41 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg PROPN
# Ex-ministro NOUN
# e CCONJ
# outros PRON
# : PUNCT
# Servi PROPN
# ... PUNCT
#
#  SPACE
# 14 NUM
#     SPACE
# " PUNCT
# La PROPN
# La PROPN
# Land PROPN
# : PUNCT
# Cantando VERB
# Estações PROPN
# " PUNCT
# arrasa NOUN
# no ADP
# Glob PROPN
# ... PUNCT
#
#  SPACE
# 91 NUM
#     SPACE
# # ADV
# musicagratis PROPN
# Ministério PROPN
# Público PROPN
# de ADP
# Minas PROPN
# Gera PROPN
# ... PUNCT
#
#  SPACE
# 5 NUM
#      SPACE
# " PUNCT
# bom ADJ
# é AUX
# bandido VERB
# morto"\nDeputado VERB
# Cabo PROPN
# Júlio PROPN
# é AUX
# ... PUNCT
#
#  SPACE
# 94 NUM
#     SPACE
# # ADV
# noticiasdorenan ADJ
# Governo PROPN
# de ADP
# Minas PROPN
# Gerais PROPN
# recon ADJ
# ... PUNCT
#
#  SPACE
# 25 NUM
#     SPACE
# " PUNCT
# uso NOUN
# de ADP
# aeronave NOUN
# pertencente ADJ
# ao ADP
#   SPACE
# Estado NOUN
# de ADP
# MG PROPN
# , PUNCT
# ... PUNCT
#
#  SPACE
# 7 NUM
#      SPACE
# " PUNCT
# A DET
# gigantesca ADJ
# barba ADJ
# do ADP
# mal NOUN
# " PUNCT
# em ADP
# destaque NOUN
# no ADP
# cad PROPN
# ... PUNCT
#
#  SPACE
# 31 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg PROPN
# Caos PROPN
# nos ADP
# presídios NOUN
# : PUNCT
# AM PROPN
# pede VERB
# ... PUNCT
#
#  SPACE
# 60 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg PROPN
# UOL PROPN
# Confere PROPN
# : PUNCT
# Governo PROPN
# Temer PROPN
# ... PUNCT
#
#  SPACE
# 69 NUM
#     SPACE
# # NOUN
# holachilevierneschico ADJ
# jajaja ADJ
# los PROPN
# wns PROPN
# preparad NOUN
# ... PUNCT
#
#  SPACE
# 58 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg NOUN
# ' PUNCT
# Tinha AUX
# que SCONJ
# matar VERB
# mais ADV
# ' PUNCT
# : PUNCT
# Sec PROPN
# ... PUNCT
#
#  SPACE
# 97 NUM
#     SPACE
# # ADV
# OperacaoBetaLab ADJ
# # NOUN
# TimBeta ADJ
# # NOUN
# Beta VERB
# # NOUN
# BetaLab ADJ
# # NOUN
# Beta PROPN
# ... PUNCT
#
#  SPACE
# 17 NUM
#     SPACE
# " PUNCT
# Modelo NOUN
# de ADP
# segurança NOUN
# será AUX
# o DET
# nosso DET
# legado NOUN
# " PUNCT
# , PUNCT
# diz VERB
# ... PUNCT
#
#  SPACE
# 48 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg VERB
# Muitas DET
# páginas NOUN
# de ADP
# investiga NOUN
# ... PUNCT
#
#  SPACE
# 16 NUM
#     SPACE
# " PUNCT
# Mesmo ADV
# sem ADP
# muito DET
# dinheiro NOUN
# no ADP
# caixa NOUN
# o DET
# governo NOUN
# d VERB
# ... PUNCT
#
#  SPACE
# 50 NUM
#     SPACE
# # ADV
# beta VERB
# # ADV
# betalab VERB
# # ADV
# mg PROPN
# Nova ADJ
# chacina NOUN
# em ADP
# presídio NOUN
# : PUNCT
# P PROPN
# ... PUNCT
#
#  SPACE
# 96 NUM
#     SPACE
# # ADV
# OperacaoBetaLab ADJ
# # NOUN
# TimBeta ADJ
# # NOUN
# Beta VERB
# # NOUN
# BetaLab ADJ
# # NOUN
# Beta PROPN
# ... PUNCT
#
#  SPACE
# 3 NUM
#                            SPACE
# � PROPN
# � PROPN
# � PROPN
# https://t.co/BnDsO34qK0 PROPN
#
#  SPACE
# Name PROPN
# : PUNCT
# Text PROPN
# , PUNCT
# dtype NOUN
# : PUNCT
# object NOUN
